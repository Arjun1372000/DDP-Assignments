# %% [markdown]
# ### **Q. Differentiate between transformations and actions in Spark. Provide at least 3 examples for each and explain their significance in execution planning.**
#
# **Transformations**
# - Operations that create a new DataFrame/RDD from an existing one
# - They are **lazy** (not executed immediately)
# - Build a logical execution plan (DAG)
#
# **Examples:**
# - `select()` → choose specific columns
# - `filter()` → apply conditions to rows
# - `groupBy()` → group data for aggregation
#
# ---
#
# **Actions**
# - Operations that trigger execution of transformations
# - Return results or write data to storage
#
# **Examples:**
# - `show()` → display data
# - `collect()` → return all data to driver
# - `count()` → return number of rows
#
# ---
#
# ### Significance in Execution Planning
# - Spark first builds a **DAG (Directed Acyclic Graph)** using transformations
# - Optimizes the plan before execution
# - Executes only when an **action** is called
# - This improves performance and minimizes unnecessary computations
#
# ---

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("TransformationsActions").getOrCreate()

# %%
data = [
    (1, "Arjun", "IT"),
    (2, "Rahul", "HR"),
    (3, "Sneha", "IT"),
    (4, "Priya", "Finance"),
    (5, "Kiran", "IT")
]

# %%
columns = ["ID", "Name", "Department"]

# %%
df = spark.createDataFrame(data, columns)

# %%
df.printSchema()
# Out:
# root
#  |-- ID: long (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Age: long (nullable = true)
#  |-- Salary: long (nullable = true)

# %%
df.show()
# Out:
# +---+-----+---+------+
# | ID| Name|Age|Salary|
# +---+-----+---+------+
# |  1|Arjun| 22| 25000|
# |  2|Rahul| 25| 35000|
# |  3|Sneha| 28| 40000|
# |  4|Priya| 24| 28000|
# |  5|Kiran| 30| 50000|
# +---+-----+---+------+

# %%
df.filter(df.Salary > 30000).show()
# Out:
# +---+-----+---+------+
# | ID| Name|Age|Salary|
# +---+-----+---+------+
# |  2|Rahul| 25| 35000|
# |  3|Sneha| 28| 40000|
# |  5|Kiran| 30| 50000|
# +---+-----+---+------+
